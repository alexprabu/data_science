# %% [markdown]
# # Itertools Module
#
#     Permutations and Combinations

# %%
import itertools

# %%
a = [1,2,3,4,5]

# %%
b = itertools.combinations(a, 1)


print(b)
print(list(b))
# Out:
# ...
# [(1,), (2,), (3,), (4,), (5,)]

# %%
b = itertools.combinations(a, 2)
print(list(b))
# Out:
# [(1, 2), (1, 3), (1, 4), (1, 5), (2, 3), (2, 4), (2, 5), (3, 4), (3, 5), (4, 5)]

# %%
b = itertools.combinations(a, 3)
print(list(b))
# Out:
# [(1, 2, 3), (1, 2, 4), (1, 2, 5), (1, 3, 4), (1, 3, 5), (1, 4, 5), (2, 3, 4), (2, 3, 5), (2, 4, 5), (3, 4, 5)]

# %%
b = itertools.combinations(a, 4)
print(list(b))
# Out:
# [(1, 2, 3, 4), (1, 2, 3, 5), (1, 2, 4, 5), (1, 3, 4, 5), (2, 3, 4, 5)]

# %%
b = itertools.combinations(a, 5)
print(list(b))
# Out:
# [(1, 2, 3, 4, 5)]

# %%
members = ['Alex', 'Sugi', 'Debbie', 'Niralya']

comb = itertools.combinations(members, 1)

print(list(comb))
# Out:
# [('Alex',), ('Sugi',), ('Debbie',), ('Niralya',)]

# %%
members = ['Alex', 'Sugi', 'Debbie', 'Niralya']

comb = itertools.combinations(members, 2)

print(list(comb))
# Out:
# [('Alex', 'Sugi'), ('Alex', 'Debbie'), ('Alex', 'Niralya'), ('Sugi', 'Debbie'), ('Sugi', 'Niralya'), ('Debbie', 'Niralya')]

# %%
members = ['Alex', 'Sugi', 'Debbie', 'Niralya']

comb = itertools.combinations(members, 3)

print(list(comb))
# Out:
# [('Alex', 'Sugi', 'Debbie'), ('Alex', 'Sugi', 'Niralya'), ('Alex', 'Debbie', 'Niralya'), ('Sugi', 'Debbie', 'Niralya')]

# %%
members = ['Alex', 'Sugi', 'Debbie', 'Niralya']

comb = itertools.combinations(members, 3)

print(list(comb))

# %% [markdown]
# Can generate combinations in Homogenious as well as  Hetrogenious data

# %%
lst = ['Alex', 'Sugi', 'Debbie', 'Niralya', 1, 2, 3, 4, True, False]

combinations_1 = itertools.combinations(lst, 1)
print(list(combinations_1), "\n")

combinations_2 = itertools.combinations(lst, 2)
print(list(combinations_2))
# Out:
# [('Alex',), ('Sugi',), ('Debbie',), ('Niralya',), (1,), (2,), (3,), (4,), (True,), (False,)]
#
# [('Alex', 'Sugi'), ('Alex', 'Debbie'), ('Alex', 'Niralya'), ('Alex', 1), ('Alex', 2), ('Alex', 3), ('Alex', 4), ('Alex', True), ('Alex', False), ('Sugi', 'Debbie'), ('Sugi', 'Niralya'), ('Sugi', 1), ('Sugi', 2), ('Sugi', 3), ('Sugi', 4), ('Sugi', True), ('Sugi', False), ('Debbie', 'Niralya'), ('Debbie', 1), ('Debbie', 2), ('Debbie', 3), ('Debbie', 4), ('Debbie', True), ('Debbie', False), ('Niralya', 1), ('Niralya', 2), ('Niralya', 3), ('Niralya', 4), ('Niralya', True), ('Niralya', False), (1, 2), (1, 3), (1, 4), (1, True), (1, False), (2, 3), (2, 4), (2, True), (2, False), (3, 4), (3, True), (3, False), (4, True), (4, False), (True, False)]

# %%
combinations = itertools.combinations(range(3), 2)

# %%
print(list(combinations))
# Out:
# [(0, 1), (0, 2), (1, 2)]

# %%
permutations = itertools.permutations(range(3), 2)

# %%
print(list(permutations))
# Out:
# [(0, 1), (0, 2), (1, 0), (1, 2), (2, 0), (2, 1)]

# %%
for i in itertools.repeat('Testing success', 12):
    print(i)
# Out:
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success

# %% [markdown]
# Below code will run continously as we didn't mention count

# %%
# for i in itertools.repeat('Testing success'):
#     print(i)

# %%
import time
for i in itertools.repeat('Testing success', 12):
    time.sleep(2)
    print(i)
# Out:
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success
# Testing success

# %%
emptyList = []
for i in itertools.repeat('item', 10):
    emptyList.append(i)
print(emptyList)
# Out:
# ['item', 'item', 'item', 'item', 'item', 'item', 'item', 'item', 'item', 'item']

# %%
lst1 = 

lst2 = ['A','B','C','D']
result2 = itertools.accumulate(lst2)
print(list(result2))
#real time example: Amazon cart
# Out:
# ['A', 'AB', 'ABC', 'ABCD']

# %%
str1 = 'ALEX PRABU'
result = itertools.cycle(str1)
for i in result:
    print(i)
# Out:
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# X
#
# P
# R
# A
# B
# U
# A
# L
# E
# ...

# %%
for x, y in itertools.product(range(3), range(3)):
    print(x,y)
    
#like  Cartesian product
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2

# %%
import time
start = time.time()
lst = [20, 30, 40]
for i in lst:
    print(i)
print("Execution time in msec: ", (time.time()- start) * 1000)
# Out:
# 20
# 30
# 40
# Execution time in msec:  0.0

# %%
import numpy as np
import time

a1 = np.array([1, 2, 3])
a2 = np.array([4, 5, 6])

# To add two array you can simply do it by
print("ADD a1 and a2 elements : ", a1+a2)

# To sub two array you can simply do it by
print("SUB a1 and a2 elements : ", a1 - a2)

# To mul two array you can simply do it by
print("MUL a1 and a2 elements : ", a1 * a2)

# Calculating time for NumPy array
start = time.time()
result = a1+a2
print("Time for NumPy array in msec: ", (time.time()- start) * 1000)
# Out:
# ADD a1 and a2 elements :  [5 7 9]
# SUB a1 and a2 elements :  [-3 -3 -3]
# MUL a1 and a2 elements :  [ 4 10 18]
# Time for NumPy array in msec:  0.0
